# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df=pd.read_csv("./csv/d.csv")
df
# Out:
#    pounds  price
# 0       1    100
# 1       2    150
# 2       3    250
# 3       4    300
# 4       5    400
# 5       6    450
# 6       7    600
# 7       8    800
# 8       9   1000
# 9      10   1500

# %%
plt.plot(df)
plt.show()

# %%
reg=LinearRegression()
reg.fit(df[["pounds"]],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[12]])
# Out:
# e:\python\panda\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1431.51515152])

# %%
plt.scatter(df.pounds,df.price,marker="p",color="red")
plt.xlabel("pounds")
plt.show()
